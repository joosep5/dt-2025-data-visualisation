# %%
pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 19.4 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
wc=WordCloud().generate("tere, ma olen joosep")

img=wc.to_image()
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import urllib.request

text = urllib.request.urlopen("https://raw.githubusercontent.com/joosep5/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/class_work/poem.txt").read().decode("utf-8")
text[50]
WordCloud().generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
WordCloud(stopwords=["and", "then", "but", "the", "to", "on"]).generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
WordCloud(stopwords=["and", "then", "but", "the", "to", "on"], background_color="white").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
from PIL import Image #import image class from PIL
import urllib.request #Library to work with URL

img =urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1o19a6yrRM6ikHr3FytSICT8nfdDA1qhK", "image1.png")

Image.open("image1.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=739x731>

# %%
from PIL import Image #import image class from PIL
import urllib.request #Library to work with URL
import numpy as np 

text = urllib.request.urlopen("https://drive.google.com/uc?export=download&id=1f6RErkEKe_WqcS5LmYEm8Zi81lR1cmk0").read().decode("utf-8")

img =urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1o19a6yrRM6ikHr3FytSICT8nfdDA1qhK", "image1.png")


WordCloud(mask=np.array(Image.open("image1.png")), background_color="green").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=739x731>
