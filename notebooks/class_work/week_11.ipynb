# %%
number=3+7;
print("The total is: ", +number)
# Out:
# The total is:  10

# %%
Name = "Joosep"
print ("Hello "+Name)
# Out:
# Hello Joosep

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in Name:
    print(letter)
# Out:
# J
# o
# o
# s
# e
# p

# %%
age = 8
if age <=7:
    print("Free")
else: print("Buy a ticket")
# Out:
# Buy a ticket

# %%
age = 8
if age <=7:
    print("Free")
elif age>=8 and age<=12:
    print("ticket is 2€")
    
else: print("Buy a ticket")
# Out:
# ticket is 2€

# %%
sentence = "racecarlevelfield"

print(sentence[0:3])
print("Print 3 letters:", sentence[0:3])
print("Print 5-9 letters:", sentence[5:9])
print("Print 5-end letters:", sentence[5:])
print("Print last letters:", sentence[-1])
print("Print last 4 letters:", sentence[-4:])
print(sentence[5:][0])
print(sentence[5:][0:5])
print(sentence[5:][:5])
print(sentence[::2])
# Out:
# rac
# Print 3 letters: rac
# Print 5-9 letters: arle
# Print 5-end letters: arlevelfield
# Print last letters: d
# Print last 4 letters: ield
# a
# arlev
# arlev
# rccreefed

# %%
sentence = "Alice went to the park and saw a beatful bird singing"

words = sentence.split(" ")

print(words)
print(words[0])
print(*words[0:3])
print(*words[-3:])
print(*words[5:][0:5])
print("the number of words", len(words))
# Out:
# ['Alice', 'went', 'to', 'the', 'park', 'and', 'saw', 'a', 'beatful', 'bird', 'singing']
# Alice
# Alice went to
# beatful bird singing
# and saw a beatful bird
# the number of words 11
